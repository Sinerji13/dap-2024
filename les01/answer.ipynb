# %% [markdown]
# <a href="https://colab.research.google.com/github/Sinerji13/dap-2024/blob/main/answer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **1. Типы ячеек в Jupyter Notebook**
#
# * **Code** — выполняемая ячейка для кода.
# * **Markdown** — форматированный текст, списки, заголовки, формулы, код.
# * **Raw NBConvert** — сырой текст для экспорта.
#
# ---
#
# # **2. Иерархический список в Markdown**
#
# ```markdown
# 1. Пункт 1
#    - Подпункт 1.1
#      1. Подподпункт 1.1.1
#    - Подпункт 1.2
# 2. Пункт 2
# ```
#
# ---
#
# # **3. Цитата в Markdown**
#
# ```markdown
# > Это пример цитаты
# > на несколько строк.
# ```
#
# ---
#
# # **4. Вставка форматированного блока кода в Markdown**
#
# ````markdown
# ```python
# def f(x):
#     return x**2
# ````
#
# ````
#
# *(в реальном Markdown — три обратные кавычки подряд)*
#
# ---
#
# # **5. Уровни заголовков в Markdown**
#
# Всего **6 уровней**:
#
# ```markdown
# # Заголовок 1
# ## Заголовок 2
# ### Заголовок 3
# #### Заголовок 4
# ##### Заголовок 5
# ###### Заголовок 6
# ````
#
# ---
#
# # **6. Шаги анализа данных + подробный разбор EDA**
#
# ## Основные шаги:
#
# 1. Постановка задачи
# 2. Сбор данных
# 3. Очистка
# 4. **EDA (Exploratory Data Analysis)**
# 5. Feature engineering
# 6. Моделирование
# 7. Оценка
# 8. Развёртывание
# 9. Отчётность и визуализация
#
# ## **Подробно: Exploratory Data Analysis**
#
# * Изучение структуры данных.
# * Проверка типов, пропусков, диапазонов.
# * Описательная статистика.
# * Поиск выбросов.
# * Корреляции.
# * Визуализации (гистограммы, boxplot, heatmap).
# * Формирование выводов для дальнейших шагов.
#
# ---
#
# # **7. Типы данных + подробный разбор числовых непрерывных**
#
# ## Основные типы:
#
# * Числовые (непрерывные/дискретные)
# * Категориальные
# * Логические
# * Временные
# * Текстовые
# * Специальные
#
# ## **Подробно: числовые непрерывные**
#
# * Принимают любые значения (рост, температура, цена).
# * Хранятся как `float64`.
# * Анализируются с помощью средних, медианы, дисперсии.
# * Визуализируются гистограммами, KDE, boxplot.
# * Обрабатываются: нормализация, устранение выбросов, заполнение пропусков.
#
# ---
#
# # **8. Что такое Jupyter Notebook**
#
# * Интерактивная среда для работы с кодом и текстом.
# * Смешивает код, результаты, графики и Markdown.
# * Используется в анализе данных, ML, обучении и прототипировании.
#
# ---
#
# # **9. Почему Python популярен в анализе данных**
#
# * Богатая экосистема (`pandas`, `numpy`, `sklearn`).
# * Простота синтаксиса.
# * Большое сообщество.
# * Удобная визуализация.
# * Хорошо подходит для быстрой исследовательской работы.
#
# ---
#
# # **10. Обязательно ли использовать Jupyter Notebook?**
#
# Нет. Можно использовать:
#
# * `.py`-скрипты
# * VS Code / PyCharm
# * Google Colab
# * JupyterLab
# * Пайплайны (Airflow, Prefect, Kedro)
